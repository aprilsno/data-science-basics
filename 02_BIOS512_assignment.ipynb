# %% [markdown]
# # BIOS512 Assignment #2

# %% [markdown]
# ### Sara O'Brien

# %% [markdown]
# 📚 Import the `tidyverse` and the `palmerpenguins` packages. (**Hint:** use the `library` function)

# %%
library(tidyverse)
library(palmerpenguins)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# Use `geom_bar` to make a histogram of penguin counts by `year`.

# %%
p1 = ggplot(penguins, aes(year)) + geom_bar()

p1
# Out:
# plot without title

# %% [markdown]
# Make a histogram or KDE plot that shows the distribution of body mass in each year. *Use a different theme than the default.*

# %%
p2 = (ggplot(penguins, aes(x = body_mass_g)) 
      + geom_histogram(fill='pink', color='pink', alpha=0.6) 
      + facet_wrap(~year, ncol=1)
      + theme_light()
      + labs(title = "Histograms of Body Mass of Penguins (g) from 2007-2009", x = "Body Mass (g)", y = "Number of Penguins")
      + theme(plot.title = element_text(hjust = 0.5)))

# Additional code added to change graph axes and title

options(repr.plot.width=6, repr.plot.height=6)

p2
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 2 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# 🎉**BONUS**: can you adjust the `x-axis` labels to have "comma" formatting? (**Hint:** use `comma` from the `scales` package.)

# %%
library("scales")

p2 = p2 + scale_x_continuous(labels = comma)

p2
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 2 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# 👇 Here is the chart I made for reference.

# %% [markdown]
# <img src="https://github.com/chuckpr/BIOS512/blob/main/assignments/mass_histograms3.png?raw=true" style="width:700px" />

# %% [markdown]
# Is there a difference between the body mass of male and female penguins? Use a scatter plot with jitter to compare the masses of male and female penguins. **Facet by `species` to see compare within each species-group.**

# %%
p3 = (ggplot(penguins, aes(x = body_mass_g, y = sex)) 
      + geom_point(position = position_jitter(h=0.2, w=0.2), alpha=0.5) 
      + facet_wrap(~species, ncol=1)
      + labs(x = "Body Mass (g)")
      + scale_x_continuous(labels = comma))

options(repr.plot.width=6, repr.plot.height=6)

p3
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# 👇 Here is my solution for reference.

# %% [markdown]
# <img src="https://github.com/chuckpr/BIOS512/blob/main/assignments/sex_differences_in_body_mass_within_species.png?raw=true" style="width: 600px" />
